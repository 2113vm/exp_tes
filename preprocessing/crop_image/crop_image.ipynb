# %%
from os import listdir, path
import sys
import json
from typing import Optional

import cv2
import numpy as np
import pandas as pd

from src.contour import Contour

# %%
stella_image_dir = 'data/stella/'
pricetag_image_dir = 'data/pricetag/'
csv_dir = 'data/csv/'
csv_stella = 'stella.csv'
csv_pricetag = 'pricetag.csv'
stella_crop_images_dir = 'data/crop_images_stella/'
pricetag_crop_images_dir = 'data/crop_images_pricetag/'

# %%
# DataFrame of metadata
df_stella = pd.read_csv(path.join(sys.path[1], csv_dir, csv_stella))
df_pricetag = pd.read_csv(path.join(sys.path[1], csv_dir, csv_pricetag))

# name images
file_names_stella = listdir(path.join(sys.path[1], stella_image_dir))
file_names_pricetag = listdir(path.join(sys.path[1], pricetag_image_dir))

# tags
stella_tags = ['petrol_name', 'price']
pricetag_tags = ['text', 'rubles', 'kopeks']

# %%
df_stella.head()
# Out:
#   #filename  file_size file_attributes  region_count  region_id  \
# 0    21.jpg     120983              {}             8          0
# 1    21.jpg     120983              {}             8          1
# 2    21.jpg     120983              {}             8          2
# 3    21.jpg     120983              {}             8          3
# 4    21.jpg     120983              {}             8          4
#
#                              region_shape_attributes       region_attributes
# 0  {"name":"rect","x":121,"y":217,"width":137,"he...  {"petrol_name":"G 95"}
# 1  {"name":"rect","x":281,"y":218,"width":345,"he...       {"price":"39.40"}
# 2  {"name":"rect","x":111,"y":367,"width":133,"he...    {"petrol_name":"95"}
# 3  {"name":"rect","x":281,"y":376,"width":354,"he...       {"price":"38.50"}
# 4  {"name":"rect","x":99,"y":536,"width":147,"hei...    {"petrol_name":"92"}

# %%
df_pricetag.head()
# Out:
#   #filename  file_size file_attributes  region_count  region_id  \
# 0    30.jpg    1182815              {}             4          0
# 1    30.jpg    1182815              {}             4          1
# 2    30.jpg    1182815              {}             4          2
# 3    30.jpg    1182815              {}             4          3
# 4    29.jpg    1121896              {}             5          0
#
#                              region_shape_attributes  \
# 0  {"name":"rect","x":393,"y":303,"width":2821,"h...
# 1  {"name":"rect","x":370,"y":610,"width":2927,"h...
# 2  {"name":"rect","x":1782,"y":913,"width":1349,"...
# 3  {"name":"rect","x":3300,"y":952,"width":527,"h...
# 4  {"name":"rect","x":80,"y":202,"width":2612,"he...
#
#                      region_attributes
# 0   {"text":"ЙОГУРТ НАТУРЕЛЬ 2,5% НА"}
# 1  {"text":"ТОП.МОЛОКЕ Б/САХ.СТ.125Г"}
# 2                      {"rubles":"21"}
# 3                      {"kopeks":"50"}
# 4      {"text":"Десерт Чудо молочный"}

# %%
def get_contours_by_metadata(image_name: str,
                            tag: str,
                            metadata: pd.DataFrame) -> Optional[Contour]:
    image_area_tags = (metadata[metadata['#filename'] == image_name]
                       .region_attributes
                       .apply(lambda attr: list(json.loads(attr).keys())[0]))

    metadata_for_image = metadata[(metadata['#filename'] == image_name) & (image_area_tags == tag)]

    if metadata_for_image.shape[0] == 0:
        return None
    
    series_image_shape = metadata_for_image['region_shape_attributes'].apply(json.loads)
    series_region_name = metadata_for_image['region_attributes'].apply(json.loads)
    
    contours = []
    
    for region_name, image_shape in zip(series_region_name, series_image_shape):
        
        contour = Contour(bounding_rect=(image_shape['x'], image_shape['y'],
                                         image_shape['width'], image_shape['height']))
        contours.append([region_name[tag], contour])
        
    return contours


def crop_image(image, contour):
    x_min, y_min, width, height = contour.bounding_rect
    x_max, y_max = x_min + width, y_min + height
    return image[y_min:y_max, x_min:x_max]


def save_crop(tags, file_names, metadata, input_dir, output_dir):
    df_info = []
    for tag in tags:
        for file_name in file_names:
            try:
                contours = get_contours_by_metadata(image_name=file_name, tag=tag, metadata=metadata)
                k = 0
                for contour_info in contours:
                    info, contour = contour_info
                    image = cv2.imread(path.join(sys.path[1], input_dir, file_name))
                    if image is None:
                        print(1)
                    else:
                        crop = crop_image(image=image, contour=contour)
                        cv2.imwrite(path.join(sys.path[1], output_dir, str(k) + tag + file_name), crop)
                        df_info.append([str(k) + tag + file_name, info])
                        k += 1
            except IndexError:
                print(file_name)
    return df_info

# %%
# contours = get_contours_by_metadata(file_name, tag, df_pricetag)
get_contours_by_metadata(image_name='13.jpg', tag='text', metadata=df_pricetag)
# Out:
# [['Салфетки влажные', <src.contour.Contour at 0x7efc43c52ef0>],
#  ['детские 60шт PL', <src.contour.Contour at 0x7efc43c52828>]]

# %%
# save crop images for stella
df_crop_stella = save_crop(tags=stella_tags, 
                           file_names=file_names_stella,
                           metadata=df_stella, 
                           input_dir=stella_image_dir, 
                           output_dir=stella_crop_images_dir)

# %%
# save crop images for pricetag
df_crop_pricetag = save_crop(tags=pricetag_tags, 
                             file_names=file_names_pricetag, 
                             metadata=df_pricetag, 
                             input_dir=pricetag_image_dir, 
                             output_dir=pricetag_crop_images_dir)

# %%
df_crop_pricetag = pd.DataFrame(data=df_crop_pricetag, columns=['filename', 'attribute'])

# %%
df_crop_stella = pd.DataFrame(data=df_crop_stella, columns=['filename', 'attribute'])

# %%
df_crop_pricetag.head()
# Out:
#       filename                 attribute
# 0   0text4.jpg                   Булочка
# 1   1text4.jpg  100г с яблочной начинкой
# 2   2text4.jpg      Первый хлебокомбинат
# 3  0text17.jpg                      Торт
# 4  1text17.jpg                1 Х/К 500Г

# %%
df_crop_stella.head()
# Out:
#              filename attribute
# 0   0petrol_name4.jpg        ДТ
# 1   1petrol_name4.jpg        92
# 2   2petrol_name4.jpg        95
# 3   3petrol_name4.jpg        95
# 4  0petrol_name17.jpg        98

# %%
df_crop_pricetag.to_csv(path.join(sys.path[1], csv_dir, 'df_crop_pricetag'), index=False)

# %%
df_crop_stella.to_csv(path.join(sys.path[1], csv_dir, 'df_crop_stella'), index=False)
